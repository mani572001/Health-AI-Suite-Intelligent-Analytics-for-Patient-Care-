# %%
#Import Libaries
import os
import pandas as pd
import numpy as np

# %%
#Load Dataset
df = pd.read_csv("../data/raw/healthcare_dataset.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (5000, 26)
#    age  gender admission_type insurance_type        bmi  systolic_bp  \
# 0   69    Male       Elective     Government  24.198234   152.149985
# 1   32  Female       Elective     Government  26.123209   156.112911
# 2   89    Male       Elective     Government  27.658751    94.454724
# 3   78    Male      Emergency        Private  28.812254   139.520216
# 4   38    Male      Emergency        Private  26.925373   103.863573
#
#    diastolic_bp  blood_glucose  cholesterol  heart_rate  ...  num_conditions  \
# 0     91.246475     165.344609   210.342343   88.465785  ...               3
# 1     74.901063     138.279525   225.434062   65.557307  ...               2
# 2     73.024929      99.496088   153.370278   98.588967  ...               1
# 3     85.082641      70.000000          NaN   68.357545  ...               0
# 4     70.255702      70.000000   167.883664   73.221997  ...               1
#
#    num_procedures  num_medications  icu_admission  risk_score risk_category  \
# 0               0                3              0          12        Medium
# 1               0                6              0           7        Medium
# 2               1                5              0           4           Low
# 3               1                4              0           4           Low
# 4               0                3              0           4           Low
#
#    length_of_stay  total_claim_cost  payer_coverage  \
# 0       10.548150      21709.929543             0.6
# 1        7.630583      15452.946210             0.6
# 2        4.674591       9315.500867             0.6
# 3        9.685285      20720.812733             0.8
# 4        9.780789      18763.532501             0.8
#
#                             patient_feedback
# 0  Good treatment but waiting time was long.
# 1         Unsatisfied with hospital service.
# 2                Average experience overall.
# 3                Average experience overall.
# 4         Unsatisfied with hospital service.
#
# [5 rows x 26 columns]

# %%
#Check for missing values
missing_percent = df.isnull().mean() * 100
print("Missing %:\n")
print(missing_percent[missing_percent > 0])
# Out:
# Missing %:
#
# bmi              14.58
# blood_glucose    14.84
# cholesterol      15.04
# hemoglobin       15.26
# creatinine       14.72
# dtype: float64

# %%
#Separate numerical and categorical columns
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = df.select_dtypes(include=["object"]).columns

print("Numeric Columns:", len(numeric_cols))
print("Categorical Columns:", len(categorical_cols))
# Out:
# Numeric Columns: 20
# Categorical Columns: 6

# %%
#Handle missing values
#For numeric columns, we can fill missing values with the median
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())
    #For categorical columns, we can fill missing values with the mode
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
#confirm no missing values remain
print("Remaining Missing:"),
df.isnull().sum()
# Out:
# Remaining Missing:
# age                 0
# gender              0
# admission_type      0
# insurance_type      0
# bmi                 0
# systolic_bp         0
# diastolic_bp        0
# blood_glucose       0
# cholesterol         0
# heart_rate          0
# hemoglobin          0
# creatinine          0
# diabetes            0
# hypertension        0
# heart_disease       0
# smoking_status      0
# num_conditions      0
# num_procedures      0
# num_medications     0
# icu_admission       0
# risk_score          0
# risk_category       0
# length_of_stay      0
# total_claim_cost    0
# payer_coverage      0
# patient_feedback    0
# dtype: int64

# %%
#Outlier Capping (IQR method)
def cap_outliers(data, cols):
    for col in cols:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        data[col] = np.where(data[col] < lower, lower,
                      np.where(data[col] > upper, upper,
                               data[col]))
    return data

cols_to_cap = [col for col in numeric_cols if col not in ["length_of_stay"]]

df = cap_outliers(df, cols_to_cap)

print("Outlier capping completed.")
# Out:
# Outlier capping completed.

# %%
#Feature Engineering: Create new features
df["pulse_pressure"] = df["systolic_bp"] - df["diastolic_bp"]

# %%
#Clinical severity score (simple sum of abnormal values)
df["clinical_severity"] = (
    (df["systolic_bp"] > 150).astype(int) +
    (df["blood_glucose"] > 180).astype(int) +
    (df["creatinine"] > 1.4).astype(int)
)

# %%
#Final validation
print("Final Shape:", df.shape)
df.describe()
# Out:
# Final Shape: (5000, 28)
#                age          bmi  systolic_bp  diastolic_bp  blood_glucose  \
# count  5000.000000  5000.000000  5000.000000   5000.000000    5000.000000
# mean     53.299000    27.147156   129.942771     80.002693     132.246074
# std      20.646851     4.527984    19.604935     11.670394      41.839578
# min      18.000000    16.000000    90.000000     50.000000      70.000000
# 25%      36.000000    24.335094   115.892906     71.853340     102.361366
# 50%      53.000000    27.151418   129.766795     80.090015     129.980502
# 75%      71.000000    29.896743   143.565410     87.897914     158.698601
# max      89.000000    38.239218   185.074166    111.964775     243.204454
#
#        cholesterol   heart_rate   hemoglobin   creatinine     diabetes  ...  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean    198.703958    80.592537    13.504797     1.009944     0.281400  ...
# std      35.591180    14.817683     1.323883     0.262766     0.449727  ...
# min     120.000000    50.000000    10.378678     0.500000     0.000000  ...
# 25%     176.365058    70.125595    12.733692     0.843332     0.000000  ...
# 50%     199.107210    80.477799    13.508520     1.008332     0.000000  ...
# 75%     220.229083    90.912797    14.303702     1.166279     1.000000  ...
# max     286.025120   122.093599    16.658717     1.650700     1.000000  ...
#
#        num_conditions  num_procedures  num_medications  icu_admission  \
# count     5000.000000     5000.000000      5000.000000         5000.0
# mean         1.249900        1.426700         4.961200            0.0
# std          0.927347        1.095453         2.182716            0.0
# min          0.000000        0.000000         0.000000            0.0
# 25%          1.000000        1.000000         3.000000            0.0
# 50%          1.000000        1.000000         5.000000            0.0
# 75%          2.000000        2.000000         6.000000            0.0
# max          3.500000        3.500000        10.500000            0.0
#
#         risk_score  length_of_stay  total_claim_cost  payer_coverage  \
# count  5000.000000     5000.000000       5000.000000     5000.000000
# mean      6.287600        9.323610      20618.116692        0.653900
# std       3.828762        4.656670       9186.188903        0.175929
# min       0.000000        1.000000        500.000000        0.300000
# 25%       4.000000        6.184493      14096.883475        0.600000
# 50%       6.000000        8.532612      19377.151987        0.800000
# 75%       8.000000       11.130218      25116.859285        0.800000
# max      14.000000       27.431176      41646.823000        0.800000
#
#        pulse_pressure  clinical_severity
# count     5000.000000        5000.000000
# mean        49.940078           0.379400
# std         22.918818           0.578206
# min        -21.964775           0.000000
# 25%         33.858757           0.000000
# 50%         49.215468           0.000000
# 75%         65.182431           1.000000
# max        130.693228           3.000000
#
# [8 rows x 22 columns]

# %%
os.makedirs("../data/processed", exist_ok=True)

df.to_csv("../data/processed/cleaned_dataset.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.
